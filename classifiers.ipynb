# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report

# %%
df = pd.read_csv('data_person_name.csv')
df.head()
# Out:
#                                             Sentence  \
# 0  Is Shahrukh khans stardom fading after FAN movie?
# 1  What do you think about Ananya Pandey's acting...
# 2  If Indians don't have a problem with Akshay Ku...
# 3  Can Virat Kohli surpass Shahrukh Khan in the f...
# 4  Why is it an issue with people whether Akshay ...
#
#                            key  \
# 0               Shahrukh khans
# 1              Ananya Pandey's
# 2  Akshay Kumar's-Aamir Khan's
# 3    Virat Kohli-Shahrukh Khan
# 4                 Akshay Kumar
#
#                                                  guj                   keyguj  \
# 0     ફેન મુવી પછી શાહરૂખ ખાનની મહત્તા ઓછી થઈ રહી છે               શાહરૂખ ખાન
# 1            અન્ય પાંડેની આ કટિંગ વિશે શું કહેવું છે               અન્ય પાંડે
# 2  લોકોને અક્ષયકુમારની કેનેડા સિટીઝનશિપ ટી કોઈ તક...               અક્ષયકુમાર
# 3  શું ભવિષ્યમાં વિરાટ કોહલી શાહરુખ ખાન કરતાં વધા...  વિરાટ કોહલી-શાહરુખ ખાન
# ...

# %%
df = pd.read_csv('data_person_name.csv')
df.head()
# Out:
#                                             Sentence  \
# 0  Is Shahrukh khans stardom fading after FAN movie?
# 1  What do you think about Ananya Pandey's acting...
# 2  If Indians don't have a problem with Akshay Ku...
# 3  Can Virat Kohli surpass Shahrukh Khan in the f...
# 4  Why is it an issue with people whether Akshay ...
#
#                            key  \
# 0               Shahrukh khans
# 1              Ananya Pandey's
# 2  Akshay Kumar's-Aamir Khan's
# 3    Virat Kohli-Shahrukh Khan
# 4                 Akshay Kumar
#
#                                                  guj                   keyguj  \
# 0     ફેન મુવી પછી શાહરૂખ ખાનની મહત્તા ઓછી થઈ રહી છે               શાહરૂખ ખાન
# 1            અન્ય પાંડેની આ કટિંગ વિશે શું કહેવું છે               અન્ય પાંડે
# 2  લોકોને અક્ષયકુમારની કેનેડા સિટીઝનશિપ ટી કોઈ તક...               અક્ષયકુમાર
# 3  શું ભવિષ્યમાં વિરાટ કોહલી શાહરુખ ખાન કરતાં વધા...  વિરાટ કોહલી-શાહરુખ ખાન
# ...

# %%
df.isnull()
# Out:
#     Sentence    key    guj  keyguj    hin  keyhin
# 0      False  False  False   False  False   False
# 1      False  False  False   False  False   False
# 2      False  False  False   False  False   False
# 3      False  False  False   False  False   False
# 4      False  False  False   False  False   False
# 5      False  False  False   False  False   False
# 6      False  False  False   False  False   False
# 7      False  False  False   False  False   False
# 8      False  False  False   False  False   False
# 9      False  False  False   False  False   False
# 10     False  False  False   False  False   False
# 11     False  False  False   False  False   False
# 12     False  False  False   False  False   False
# 13     False  False  False   False  False   False
# 14     False  False  False   False  False   False
# 15     False  False  False   False  False   False
# 16     False  False  False   False  False   False
# 17     False  False  False   False  False   False
# ...

# %%
df.isnull().sum()
# Out:
# Sentence    0
# key         6
# guj         0
# keyguj      7
# hin         0
# keyhin      6
# dtype: int64

# %%
df = df.fillna(method='ffill')

# %%
clear

# %%
clear

# %%
df.groupby('key').size().reset_index(name='counts')
print(df)
X = df.drop('key', axis=1)
v = DictVectorizer(sparse=False)
X = v.fit_transform(X.to_dict('records'))
y=df.key.values
classes = np.unique(y)
classes = classes.tolist()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state=0)
X_train.shape, y_train.shape
# Out:
#                                              Sentence  \
# 0   Is Shahrukh khans stardom fading after FAN movie?
# 1   What do you think about Ananya Pandey's acting...
# 2   If Indians don't have a problem with Akshay Ku...
# 3   Can Virat Kohli surpass Shahrukh Khan in the f...
# 4   Why is it an issue with people whether Akshay ...
# 5   What if Shahrukh Khan takes the place of Rober...
# 6   Will Salman Khan Movie Bharat break the record...
# 7   Whose role was played by Vicky Kaushal in URI ...
# 8        Which are the top 3 movies of Kajol and SRK?
# 9   Do you think it's right to question Akshay Kum...
# 10  What is the actual profession of Poonam Pandey...
# 11  Why did Ashutosh Gowariker, who made a cinemat...
# 12  Who is the Bollywood celebrity, Bindiya Goswam...
# 13  Is Siddharth Chopra an egoistic and insensitiv...
# 14  Did Priyanka Chopra's brother mistreat Ishita ...
# 15  Among Tara Sutaria, Ananya Panday, Sara Ali Kh...
# ...

# %%
per = Perceptron(verbose=10, n_jobs=-1, max_iter=5)
per.partial_fit(X_train, y_train, classes)
# Out:
# -- Epoch 1-- Epoch 1
#
# Norm: 3.87, NNZs: 15, Bias: -1.000000, T: 34, Avg. loss: 0.029412Norm: 2.24, NNZs: 5, Bias: -1.000000, T: 34, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
#
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 2.24, NNZs: 5, Bias: -1.000000, T: 34, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 2.24, NNZs: 5, Bias: -1.000000, T: 34, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# -- Epoch 1
# -- Epoch 1-- Epoch 1
# Norm: 3.87, NNZs: 15, Bias: -1.000000, T: 34, Avg. loss: 0.029412
# Total training time: 0.00 seconds.
# Norm: 2.24, NNZs: 5, Bias: -1.000000, T: 34, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
#
# Norm: 3.87, NNZs: 15, Bias: -1.000000, T: 34, Avg. loss: 0.029412-- Epoch 1
#
# Norm: 3.87, NNZs: 15, Bias: -1.000000, T: 34, Avg. loss: 0.029412
# Total training time: 0.00 seconds.
# Total training time: 0.00 seconds.
# -- Epoch 1
# ...

# %%
print(classification_report(y_pred=per.predict(X_test), y_true=y_test, labels=df['key']))
# Out:
#                                                         precision    recall  f1-score   support
#
#                                         Shahrukh khans       0.00      0.00      0.00         0
#                                        Ananya Pandey's       0.00      0.00      0.00         0
#                            Akshay Kumar's-Aamir Khan's       0.00      0.00      0.00         1
#                              Virat Kohli-Shahrukh Khan       0.00      0.00      0.00         0
#                                           Akshay Kumar       0.00      0.00      0.00         2
#                            Shahrukh Khan-Robert Downey       0.00      0.00      0.00         0
#                                            Salman Khan       0.00      0.00      0.00         0
#                                          Vicky Kaushal       0.00      0.00      0.00         1
#                                              Kajol-SRK       0.00      0.00      0.00         0
# ...

# %%
sgd = SGDClassifier()
sgd.partial_fit(X_train, y_train, classes)
print(classification_report(y_pred=sgd.predict(X_test), y_true=y_test, labels=df['key']))
# Out:
#                                                         precision    recall  f1-score   support
#
#                                         Shahrukh khans       0.00      0.00      0.00         0
#                                        Ananya Pandey's       0.00      0.00      0.00         0
#                            Akshay Kumar's-Aamir Khan's       0.00      0.00      0.00         1
#                              Virat Kohli-Shahrukh Khan       0.00      0.00      0.00         0
#                                           Akshay Kumar       0.00      0.00      0.00         2
#                            Shahrukh Khan-Robert Downey       0.00      0.00      0.00         0
#                                            Salman Khan       0.00      0.00      0.00         0
#                                          Vicky Kaushal       0.00      0.00      0.00         1
#                                              Kajol-SRK       0.00      0.00      0.00         0
# ...

# %%
nb = MultinomialNB(alpha=0.01)
nb.partial_fit(X_train, y_train, classes)
print(classification_report(y_pred=nb.predict(X_test), y_true=y_test, labels = df['key']))
# Out:
#                                                         precision    recall  f1-score   support
#
#                                         Shahrukh khans       0.00      0.00      0.00         0
#                                        Ananya Pandey's       0.00      0.00      0.00         0
#                            Akshay Kumar's-Aamir Khan's       0.00      0.00      0.00         1
#                              Virat Kohli-Shahrukh Khan       0.00      0.00      0.00         0
#                                           Akshay Kumar       0.00      0.00      0.00         2
#                            Shahrukh Khan-Robert Downey       0.00      0.00      0.00         0
#                                            Salman Khan       0.00      0.00      0.00         0
#                                          Vicky Kaushal       0.00      0.00      0.00         1
#                                              Kajol-SRK       0.00      0.00      0.00         0
# ...

# %%
pa =PassiveAggressiveClassifier()
pa.partial_fit(X_train, y_train, classes)
print(classification_report(y_pred=pa.predict(X_test), y_true=y_test, labels = df['key']))
# Out:
#                                                         precision    recall  f1-score   support
#
#                                         Shahrukh khans       0.00      0.00      0.00         0
#                                        Ananya Pandey's       0.00      0.00      0.00         0
#                            Akshay Kumar's-Aamir Khan's       0.00      0.00      0.00         1
#                              Virat Kohli-Shahrukh Khan       0.00      0.00      0.00         0
#                                           Akshay Kumar       0.00      0.00      0.00         2
#                            Shahrukh Khan-Robert Downey       0.00      0.00      0.00         0
#                                            Salman Khan       0.00      0.00      0.00         0
#                                          Vicky Kaushal       0.00      0.00      0.00         1
#                                              Kajol-SRK       0.00      0.00      0.00         0
# ...
